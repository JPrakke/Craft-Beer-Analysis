# %%
import pandas as pd
import connection
from connection import password
from sqlalchemy import create_engine

# %%
breweries_file = "../resources/breweries.csv"
breweriesDF = pd.read_csv(breweries_file)
breweriesDF.set_index("brewery_id", inplace=True)

breweriesDF.head()
# Out:
#                                  name           city state
# brewery_id
# 0                  NorthGate Brewing     Minneapolis    MN
# 1           Against the Grain Brewery     Louisville    KY
# 2            Jack's Abby Craft Lagers     Framingham    MA
# 3           Mike Hess Brewing Company      San Diego    CA
# 4             Fort Point Beer Company  San Francisco    CA

# %%
final_cleaned_beer_file = "../resources/final_cleaned_beer_4.csv"
cleanedbeerDF = pd.read_csv(final_cleaned_beer_file, encoding = 'utf-8')
cleanedbeerDF = cleanedbeerDF[['brewery_id','abv','ibu','name','style','ounces']]
cleanedbeerDF = cleanedbeerDF.reset_index()
cleanedbeerDF.set_index("index",inplace=True)
cleanedbeerDF = cleanedbeerDF.reset_index()
cleanedbeerDF = cleanedbeerDF.rename(columns={'index':'id'})
cleanedbeerDF.set_index("id",inplace=True)
cleanedbeerDF
# Out:
#       brewery_id    abv  ibu                                         name  \
# id
# 0            177  0.061   60                                 Bitter Bitch
# 1            368  0.099   92                                Lower De Boom
# 2            368  0.079   45                                Fireside Chat
# 3            368  0.044   42                              Bitter American
# 4            368  0.049   17         Hell or High Watermelon Wheat (2009)
# 5            368  0.049   17         Hell or High Watermelon Wheat (2009)
# 6            368  0.049   17  21st Amendment Watermelon Wheat Beer (2006)
# 7            368  0.070   70                    21st Amendment IPA (2006)
# 8            368  0.070   70                 Brew Free! or Die IPA (2008)
# 9            368  0.070   70                 Brew Free! or Die IPA (2009)
# 10           368  0.085   52         Special Edition: Allies Win The War!
# 11           368  0.097   94                                   Hop Crisis
# 12           368  0.044   42                       Bitter American (2011)
# 13           368  0.079   45                         Fireside Chat (2010)
# 14           368  0.068   65                                Back in Black
# 15           368  0.083   35                                 Monk's Blood
# 16           368  0.070   65                        Brew Free! or Die IPA
# 17           368  0.049   17                Hell or High Watermelon Wheat
# 18            67  0.070   82                                 Bimini Twist
# 19            60  0.035   11                        Passion Fruit Prussia
# 20            60  0.045   18                                    Send Help
# 21            60  0.050   28                                 Contact High
# 22            27  0.050   45                                    Citrafest
# 23            27  0.069   65                                    Scarecrow
# 24            27  0.090   50                                      Ironman
# 25            27  0.046   15                                 Honey Kolsch
# 26            27  0.052   18                             Copperhead Amber
# 27           481  0.059   75                              Rude Parrot IPA
# 28           481  0.054   30                      British Pale Ale (2010)
# 29           481  0.054   30                             British Pale Ale
# ...          ...    ...  ...                                          ...
# 1370         361  0.082  100                        Hop Slayer Double IPA
# 1371         361  0.052   27                                  Phat Chance
# 1372         361  0.082  100                 Hop Slayer Double IPA (2011)
# 1373         361  0.082  100                 Hop Slayer Double IPA (2011)
# 1374         361  0.042   13                        Wild Onion Summer Wit
# 1375         361  0.060   23                                   Jack Stout
# 1376         361  0.056   41                               Paddy Pale Ale
# 1377         181  0.068   21                                 Blonde Hunny
# 1378         181  0.057   20       Wild Wolf Wee Heavy Scottish Style Ale
# 1379         181  0.045   25                   Wild Wolf American Pilsner
# 1380         181  0.051   45                                    Alpha Ale
# 1381         509  0.074   83                                      Ace IPA
# 1382         509  0.080   31                                  P-51 Porter
# 1383         211  0.071   60                         #002 American I.P.A.
# 1384         211  0.048   38                          #004 Session I.P.A.
# 1385         239  0.062   61                        Ananda India Pale Ale
# 1386         239  0.045   23                                    Tiny Bomb
# 1387          14  0.058   72                                 Train Hopper
# 1388         344  0.059  135                           Troopers Alley IPA
# 1389         402  0.047   15                      Wolverine Premium Lager
# 1390         109  0.065   82                              4000 Footer IPA
# 1391         109  0.028   15                                  Summer Brew
# 1392         339  0.065   69                                 Be Hoppy IPA
# 1393         199  0.069   69                                   Worthy IPA
# 1394         199  0.045   25                              Easy Day Kolsch
# 1395         199  0.077   30         Lights Out Vanilla Cream Extra Stout
# 1396         199  0.069   69                            Worthy IPA (2013)
# 1397         199  0.060   50                                  Worthy Pale
# 1398         424  0.067   45                                    Belgorado
# 1399         424  0.055   40                          Silverback Pale Ale
#
#                                style  ounces
# id
# 0            American Pale Ale (APA)    12.0
# 1                American Barleywine     8.4
# 2                      Winter Warmer    12.0
# 3            American Pale Ale (APA)    12.0
# 4             Fruit / Vegetable Beer    12.0
# 5             Fruit / Vegetable Beer    12.0
# 6             Fruit / Vegetable Beer    12.0
# 7                       American IPA    12.0
# 8                       American IPA    12.0
# 9                       American IPA    12.0
# 10                English Strong Ale    12.0
# 11    American Double / Imperial IPA    12.0
# 12           American Pale Ale (APA)    12.0
# 13                     Winter Warmer    12.0
# 14                American Black Ale    12.0
# 15                  Belgian Dark Ale    12.0
# 16                      American IPA    12.0
# 17            Fruit / Vegetable Beer    12.0
# 18                      American IPA    12.0
# 19                Berliner Weissbier    12.0
# 20               American Blonde Ale    12.0
# 21           American Pale Wheat Ale    12.0
# 22                      American IPA    16.0
# 23                      American IPA    16.0
# 24                English Strong Ale    16.0
# 25                            Kolsch    16.0
# 26                  Belgian Dark Ale    16.0
# 27                      American IPA    16.0
# 28                  English Pale Ale    16.0
# 29                  English Pale Ale    16.0
# ...                              ...     ...
# 1370  American Double / Imperial IPA    12.0
# 1371             American Blonde Ale    12.0
# 1372  American Double / Imperial IPA    12.0
# 1373  American Double / Imperial IPA    12.0
# 1374                         Witbier    12.0
# 1375                   Oatmeal Stout    12.0
# 1376         American Pale Ale (APA)    12.0
# 1377                Belgian Pale Ale    12.0
# 1378          Scotch Ale / Wee Heavy    12.0
# 1379                American Pilsner    12.0
# 1380         American Pale Ale (APA)    12.0
# 1381                    American IPA    16.0
# 1382                 American Porter    16.0
# 1383                    American IPA    12.0
# 1384                    American IPA    12.0
# 1385                    American IPA    12.0
# 1386                American Pilsner    12.0
# 1387                    American IPA    12.0
# 1388                    American IPA    12.0
# 1389             American Pale Lager    12.0
# 1390                    American IPA    12.0
# 1391                American Pilsner    12.0
# 1392                    American IPA    16.0
# 1393                    American IPA    12.0
# 1394                          Kolsch    12.0
# 1395  American Double / Imperial IPA    12.0
# 1396                    American IPA    12.0
# 1397         American Pale Ale (APA)    12.0
# 1398                     Belgian IPA    12.0
# 1399         American Pale Ale (APA)    12.0
#
# [1400 rows x 6 columns]

# %%
connection_string = (f"root:{password}@localhost/craftbeerDB")
engine = create_engine(f'mysql://{connection_string}',encoding='utf-8')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['beer', 'breweries']

# %%
# Load Data from Pandas DF to DB Tables
breweriesDF.to_sql(
    name='breweries', con=engine, 
    if_exists='append', index=True)

# %%
# Load Data from Pandas DF to DB Tables
cleanedbeerDF.to_sql(
    name='beer', con=engine, 
    if_exists='append', index=True)
